# %%
from bs4 import BeautifulSoup
import urllib.request       # Determine whether urllib, urllib2, or requests is best option


# Access Basketball Reference to get league leaders in win shares for each season
#specify the url
site = "https://www.basketball-reference.com/leaders/hof_prob.html"
#Query the website and return the html to the variable 'page'
page = urllib.request.urlopen(site)
#Parse the html in the 'page' variable and store it in Beautiful Soup format
soup = BeautifulSoup(page, 'lxml')

# %%
hof_prob_table = soup.table

# %%
soup.table('td')[1]
# Out:
# <td><a href="/players/a/abdulka01.html">Kareem Abdul-Jabbar</a>*
# </td>

# %%
hof_prob_table('td')[1].a.get('href'),  hof_prob_table('td')[1].a.string
# Out:
# ('/players/a/abdulka01.html', 'Kareem Abdul-Jabbar')

# %%
#create list tuples of players and href 
player_list = []
for line in hof_prob_table('td'):
    try:
        player_list.append((line.a.string, line.a.get('href')))
    except:
        print('could not do it for', line)
# Out:
# could not do it for <td>1.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>2.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>3.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>4.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>5.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>6.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>7.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>8.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>9.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>10.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>11.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>12.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>13.</td>
# could not do it for <td>1.0000</td>
# could not do it for <td>14.</td>
# ...

# %%
# using oscar robertson, figure out how to scrape his stats
player = player_list[11]
print(player)
# Out:
# ('Kevin Garnett', '/players/g/garneke01.html')

# %%
reference_site = 'https://www.basketball-reference.com'
page = urllib.request.urlopen(reference_site + player[1])
#Parse the html in the 'page' variable and store it in Beautiful Soup format
soup = BeautifulSoup(page, 'lxml')
per_game_table = soup.table

# %%
# show career stats table format
per_game_table('td')
# Out:
# [<td class="center " data-stat="age">19</td>,
#  <td class="left " data-stat="team_id"><a href="/teams/MIN/1996.html">MIN</a></td>,
#  <td class="left " data-stat="lg_id"><a href="/leagues/NBA_1996.html">NBA</a></td>,
#  <td class="center " data-stat="pos">SF</td>,
#  <td class="right " data-stat="g">80</td>,
#  <td class="right " data-stat="gs">43</td>,
#  <td class="right " data-stat="mp_per_g">28.7</td>,
#  <td class="right " data-stat="fg_per_g">4.5</td>,
#  <td class="right " data-stat="fga_per_g">9.2</td>,
#  <td class="right " data-stat="fg_pct">.491</td>,
#  <td class="right " data-stat="fg3_per_g">0.1</td>,
#  <td class="right " data-stat="fg3a_per_g">0.4</td>,
#  <td class="right " data-stat="fg3_pct">.286</td>,
#  <td class="right " data-stat="fg2_per_g">4.4</td>,
#  <td class="right " data-stat="fg2a_per_g">8.8</td>,
#  <td class="right " data-stat="fg2_pct">.499</td>,
#  <td class="right " data-stat="efg_pct">.497</td>,
# ...

# %%
soup.find_all('div', {'id':'info'})[0].find_all('span', {'itemprop':'height'})[0].string
#gets year
print(per_game_table.find_all('tbody')[0].find_all('tr', {'id':'per_game.1998'})[0].a.string)
# Out:
# <a href="/players/g/garneke01/gamelog/1998/">1997-98</a>

# %%
# access season stats for an individual player
for i in per_game_table('td')[:10]:
    print(i.get('data-stat'))
    print(i.string)
# Out:
# age
# 19
# team_id
# MIN
# lg_id
# NBA
# pos
# SF
# g
# 80
# gs
# 43
# mp_per_g
# 28.7
# fg_per_g
# 4.5
# fga_per_g
# 9.2
# fg_pct
# .491

# %%
# create list of stat categories to be used as keys
categories = ['player', 'href', 'year']
for i in per_game_table('td'):
    if i.get('data-stat') not in categories:
        categories.append(i.get('data-stat'))

# %%
# this gets category values for a single season and makes a single list
values = []
length = 0
for row in (per_game_table('tr')):
    for num, column in enumerate(row):
        # Players from different decades have different
        # available stats, but PTS is always the last column
        if column.string == 'PTS':
            length = int((num+1) / 2)
        if column != '\n':
            values.append(column.string)        

# Ignores category names
values = values[length:]

# %%
all_seasons =[]
season = [player[0], player[1]]
for value in values:
    season.append(value)
    if (len(season) == length+2):
        if season[3] == None:
            break
        else:
            all_seasons.append(season)
            season = [player[0], player[1]]

# %%
len(categories), len(all_seasons)
# Out:
# (32, 23)

# %%
print(all_seasons)
# Out:
# [['Kevin Garnett', '/players/g/garneke01.html', '1995-96', '19', 'MIN', 'NBA', 'SF', '80', '43', '28.7', '4.5', '9.2', '.491', '0.1', '0.4', '.286', '4.4', '8.8', '.499', '.497', '1.3', '1.9', '.705', '2.2', '4.1', '6.3', '1.8', '1.1', '1.6', '1.4', '2.4', '10.4'], ['Kevin Garnett', '/players/g/garneke01.html', None, '20', 'MIN', 'NBA', 'SF', '77', '77', '38.9', '7.1', '14.3', '.499', '0.1', '0.3', '.286', '7.1', '14.0', '.503', '.502', '2.7', '3.5', '.754', '2.5', '5.6', '8.0', '3.1', '1.4', '2.1', '2.3', '2.6', '17.0'], ['Kevin Garnett', '/players/g/garneke01.html', None, '21', 'MIN', 'NBA', 'PF', '82', '82', '39.3', '7.7', '15.8', '.491', '0.0', '0.2', '.188', '7.7', '15.6', '.495', '.492', '3.0', '4.0', '.738', '2.7', '6.9', '9.6', '4.2', '1.7', '1.8', '2.3', '2.7', '18.5'], ['Kevin Garnett', '/players/g/garneke01.html', '1998-99', '22', 'MIN', 'NBA', 'PF', '47', '47', '37.9', '8.8', '19.1', '.460', '0.1', '0.3', '.286', '8.7', '18.9', '.463', '.462', '3.1', '4.4', '.704', '3.5',
# ...

# %%
# This version works but includes career totals which I am not interested in
categories = ['player', 'href', 'year']
for i in per_game_table('td'):
    if i.get('data-stat') not in categories:
        categories.append(i.get('data-stat'))
all_seasons = []        
for player in player_list[:15]:
    print(player)
    reference_site = 'https://www.basketball-reference.com'
    page = urllib.request.urlopen(reference_site + player[1])
    #Parse the html in the 'page' variable and store it in Beautiful Soup format
    soup = BeautifulSoup(page, 'lxml')
    per_game_table = soup.table
    
    # this gets category values for a single season and makes a single list
    values = []
    length = 0
    for row in (per_game_table('tr')):
        for num, column in enumerate(row):
            # Players from different decades have different
            # available stats, but PTS is always the last column
            if column.string == 'PTS':
                length = int((num+1) / 2)
            if column != '\n':
                values.append(column.string)        

    # Ignores category names
    values = values[length:]

    # Create list of individual season stats lists
    player_career =[]
    season = [player[0], player[1]]
    for value in values:
        season.append(value)
        if (len(season) == length+2):
            player_career.append(season)
            season = [player[0], player[1]]
    all_seasons.append(player_career)
    print(str(len(player_career)), ' seasons of ', player[0], 'added')
# Out:
# ('Kareem Abdul-Jabbar', '/players/a/abdulka01.html')
# 24  seasons of  Kareem Abdul-Jabbar added
# ('Michael Jordan', '/players/j/jordami01.html')
# 19  seasons of  Michael Jordan added
# ('Bill Russell', '/players/r/russebi01.html')
# 14  seasons of  Bill Russell added
# ('Kobe Bryant', '/players/b/bryanko01.html')
# 21  seasons of  Kobe Bryant added
# ('Wilt Chamberlain', '/players/c/chambwi01.html')
# 21  seasons of  Wilt Chamberlain added
# ('LeBron James', '/players/j/jamesle01.html')
# 21  seasons of  LeBron James added
# ('Tim Duncan', '/players/d/duncati01.html')
# 20  seasons of  Tim Duncan added
# ("Shaquille O'Neal", '/players/o/onealsh01.html')
# 29  seasons of  Shaquille O'Neal added
# ('John Havlicek', '/players/h/havlijo01.html')
# 17  seasons of  John Havlicek added
# ('Oscar Robertson', '/players/r/roberos01.html')
# 18  seasons of  Oscar Robertson added
# ('Bob Cousy', '/players/c/cousybo01.html')
# 19  seasons of  Bob Cousy added
# ...

# %%
for player in all_seasons:
    print(player[0][0], len(player))
# Out:
# Kareem Abdul-Jabbar 24
# Michael Jordan 19
# Bill Russell 14
# Kobe Bryant 21
# Wilt Chamberlain 21
# LeBron James 21
# Tim Duncan 20
# Shaquille O'Neal 29
# John Havlicek 17
# Oscar Robertson 18
# Bob Cousy 19
# Kevin Garnett 28
# Jerry West 15
# Magic Johnson 14
# Karl Malone 23

# %%
from bs4 import BeautifulSoup
import urllib.request       # Determine whether urllib, urllib2, or requests is best option

# Access Basketball Reference to get league leaders in win shares for each season
#specify the url
site = "https://www.basketball-reference.com/leaders/hof_prob.html"
#Query the website and return the html to the variable 'page'
page = urllib.request.urlopen(site)
#Parse the html in the 'page' variable and store it in Beautiful Soup format
soup = BeautifulSoup(page, 'lxml')
hof_prob_table = soup.table

#create list tuples of players and href 
player_list = []
for line in hof_prob_table('td'):
    try:
        player_list.append((line.a.string, line.a.get('href')))
    except:
        print('could not do it for', line)
        

all_seasons = [] 
for player in player_list[:35]:
    reference_site = 'https://www.basketball-reference.com'
    page = urllib.request.urlopen(reference_site + player[1])
    #Parse the html in the 'page' variable and store it in Beautiful Soup format
    soup = BeautifulSoup(page, 'lxml')
    # Assign 
    per_game_table = soup.table
    height = soup.find_all('div', {'id':'info'})[0].find_all('span', {'itemprop':'height'})[0].string

    # this gets category values for a single season and makes a single list
    values = []
    length = 0
    for row in (per_game_table('tr')):
        for num, column in enumerate(row):
            # Players from different decades have different
            # available stats, but PTS is always the last column
            if column.string == 'PTS':
                length = int((num+1) / 2)
            if column != '\n':
                values.append(column.string)        
    categories = values[:length]
    # Ignores category names
    values = values[length:]

    # Create list of individual season stats lists
    player_career = [['player', 'href', 'height'] + categories]
    season = [player[0], player[1], height]
    for value in values:
        season.append(value)
        #added and (season[3] != None)
        if (len(season) == length+3) and (season[4] != None):
            player_career.append(season)
            season = [player[0], player[1], height]
        # Player must have played at least 12 seasons
    if len(player_career) > 12:
        all_seasons.append(player_career)
        print(str((len(player_career)-1)), ' seasons of ', player[0], 'added')
# Out:
# 20  seasons of  Kareem Abdul-Jabbar added
# 17  seasons of  Michael Jordan added
# 13  seasons of  Bill Russell added
# 20  seasons of  Kobe Bryant added
# 16  seasons of  Wilt Chamberlain added
# 16  seasons of  LeBron James added
# 19  seasons of  Tim Duncan added
# 21  seasons of  Shaquille O'Neal added
# 16  seasons of  John Havlicek added
# 14  seasons of  Oscar Robertson added
# 15  seasons of  Bob Cousy added
# 23  seasons of  Kevin Garnett added
# 14  seasons of  Jerry West added
# 14  seasons of  Magic Johnson added
# 19  seasons of  Karl Malone added
# 18  seasons of  Hakeem Olajuwon added
# 18  seasons of  Dwyane Wade added
# 21  seasons of  Dirk Nowitzki added
# 13  seasons of  Larry Bird added
# 16  seasons of  Elvin Hayes added
# 363
