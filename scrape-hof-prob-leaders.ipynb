# %%
from bs4 import BeautifulSoup
from collections import defaultdict, OrderedDict
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3
import urllib.request       # Determine whether urllib, urllib2, or requests is best option


# Access Basketball Reference to get league leaders in win shares for each season
#specify the url
site = "https://www.basketball-reference.com/leaders/hof_prob.html"
#Query the website and return the html to the variable 'page'
page = urllib.request.urlopen(site)
#Parse the html in the 'page' variable and store it in Beautiful Soup format
soup = BeautifulSoup(page)
# Out:
# C:\Users\Drew\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Drew\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
table = soup.table

# %%
soup.table('td')[1]
# Out:
# <td><a href="/players/a/abdulka01.html">Kareem Abdul-Jabbar</a>*
# </td>

# %%
table('td')[1].a.get('href'),  table('td')[1].a.string
# Out:
# ('/players/a/abdulka01.html', 'Kareem Abdul-Jabbar')

# %%
#create list tuples of players and href 
player_list = []
for line in table('td'):
    try:
        player_list.append((line.a.string, line.a.get('href')))
    except:
        print('could not do it')
# Out:
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# could not do it
# ...

# %%
# using oscar robertson, figure out how to scrape his stats
oscar = player_list[9]
print(oscar)
# Out:
# ('Oscar Robertson', '/players/r/roberos01.html')

# %%
reference_site = 'https://www.basketball-reference.com'
page = urllib.request.urlopen(reference_site + oscar[1])
#Parse the html in the 'page' variable and store it in Beautiful Soup format
soup = BeautifulSoup(page)
# Out:
# C:\Users\Drew\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Drew\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
# show career stats table format
soup.table('td')[:20]
# Out:
# [<td class="center " data-stat="age">22</td>,
#  <td class="left " data-stat="team_id"><a href="/teams/CIN/1961.html">CIN</a></td>,
#  <td class="left " data-stat="lg_id"><a href="/leagues/NBA_1961.html">NBA</a></td>,
#  <td class="center " data-stat="pos">PG</td>,
#  <td class="right " data-stat="g">71</td>,
#  <td class="right iz" data-stat="gs"></td>,
#  <td class="right " data-stat="mp_per_g">42.7</td>,
#  <td class="right " data-stat="fg_per_g">10.6</td>,
#  <td class="right " data-stat="fga_per_g">22.5</td>,
#  <td class="right " data-stat="fg_pct">.473</td>,
#  <td class="right " data-stat="ft_per_g">9.2</td>,
#  <td class="right " data-stat="fta_per_g">11.2</td>,
#  <td class="right " data-stat="ft_pct">.822</td>,
#  <td class="right iz" data-stat="orb_per_g"></td>,
#  <td class="right iz" data-stat="drb_per_g"></td>,
#  <td class="right " data-stat="trb_per_g">10.1</td>,
#  <td class="right " data-stat="ast_per_g"><strong>9.7</strong></td>,
# ...

# %%
# access season stats for an individual player
for i in soup.table('td'):
    print(i.get('data-stat'))
    print(i.string)
# Out:
# age
# 22
# team_id
# CIN
# lg_id
# NBA
# pos
# PG
# g
# 71
# gs
# None
# mp_per_g
# 42.7
# fg_per_g
# 10.6
# fga_per_g
# 22.5
# fg_pct
# .473
# ft_per_g
# 9.2
# fta_per_g
# 11.2
# ft_pct
# .822
# orb_per_g
# None
# drb_per_g
# None
# trb_per_g
# 10.1
# ast_per_g
# 9.7
# stl_per_g
# None
# blk_per_g
# None
# pf_per_g
# 3.1
# pts_per_g
# 30.5
# age
# 23
# team_id
# CIN
# lg_id
# NBA
# pos
# PG
# g
# 79
# gs
# None
# mp_per_g
# 44.3
# fg_per_g
# 11.0
# fga_per_g
# 22.9
# fg_pct
# .478
# ft_per_g
# 8.9
# fta_per_g
# 11.0
# ft_pct
# .803
# orb_per_g
# None
# drb_per_g
# None
# trb_per_g
# 12.5
# ast_per_g
# 11.4
# stl_per_g
# None
# blk_per_g
# None
# pf_per_g
# 3.3
# pts_per_g
# 30.8
# age
# 24
# team_id
# CIN
# lg_id
# NBA
# pos
# PG
# g
# 80
# gs
# None
# mp_per_g
# 44.0
# fg_per_g
# 10.3
# fga_per_g
# 19.9
# fg_pct
# .518
# ft_per_g
# 7.7
# fta_per_g
# 9.5
# ft_pct
# .810
# orb_per_g
# None
# drb_per_g
# None
# trb_per_g
# 10.4
# ast_per_g
# 9.5
# stl_per_g
# None
# blk_per_g
# None
# ...

# %%
# create
stuff = defaultdict(list)
for ind, x in enumerate(soup.table('a')):
    if not x.string.isalpha():
        key = x.string
    else:
        stuff[key].append(x.string)

# %%
new = OrderedDict(stuff)

# %%
for ind, key in enumerate(new):
    for i in soup.table('td')
# Out:
# 0 1960-61
# 1 1961-62
# 2 1962-63
# 3 1963-64
# 4 1964-65
# 5 1965-66
# 6 1966-67
# 7 1967-68
# 8 1968-69
# 9 1969-70
# 10 1970-71
# 11 1971-72
# 12 1972-73
# 13 1973-74

# %% [markdown]
# I have created an OrderedDict of a player's seasons, and I have a function to run over a players season statistics. I now need to write a function to add the season stats to the player's seasons.
