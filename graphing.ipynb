# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from cleaning import df

# %%
# Write a function that takes column and spits out graph
# of Age vs. Average of Column
  
def graph_column(col_name):
    '''Graphs the mean, lower quantile, upper quantile, minimum, and maximum
    values for a column'''
    ages = range(18,44)
    
    means = []
    lower=[]
    top=[]
    #maxi=[]
    #mini=[]
    for age in ages:
        means.append(df[df['age'] == age][col_name].mean())
        lower.append(df[df['age'] == age][col_name].quantile(.25))
        top.append(df[df['age'] == age][col_name].quantile(.75))
        #maxi.append(df[df['Age'] == age][col_name].max())
        #mini.append(df[df['Age'] == age][col_name].min())
    plt.plot(ages, means)
    #plt.plot(ages, lower)
    #plt.plot(ages, top)
    #plt.plot(ages, maxi)
    #plt.plot(ages, mini)
    plt.title('avg ' + col_name + ' vs age')
    return plt.show()

# %%
for column in df.columns:
    if (np.dtype(df[column]) == np.float64) and column != 'age':
        graph_column(column)

# %%
# Issues graphing 'gs', 'orb', 'drb','3p', '3pa','stl', 
# 'blk', or 'tov'. Need to investigate further

stat_col = ['g', 'mp', 'fg', 'fga',  '2p', '2pa', 'ft', 'fta',
             'trb', 'ast',  'pf', 'pts', 'allstar'
            ]
# create histograms of each stat at each age in order to see the progression
# of stats over time. 
for col in stat_col:
    plt.hist(df[col], bins=15, range=[0, max(df[col])])
    plt.title(col + ' frequency')
    plt.show()
# Out:
# C:\Users\Drew\Anaconda3\lib\site-packages\numpy\lib\function_base.py:748: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# C:\Users\Drew\Anaconda3\lib\site-packages\numpy\lib\function_base.py:749: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)

# %%
for col in stat_col:
    try:
        ages = range(18,44)
        for age in ages:
            val = df.loc[df['age']==age][col]
            plt.hist(val, bins=15, range = [0, max(df[col])])
            plt.title(col + ' at age ' + str(age))
            plt.show()
    except:
        print(col)
# Out:
# C:\Users\Drew\Anaconda3\lib\site-packages\numpy\lib\function_base.py:748: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# C:\Users\Drew\Anaconda3\lib\site-packages\numpy\lib\function_base.py:749: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)
