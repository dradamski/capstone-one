# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import seaborn as sns

from cleaning import df

# Set graph style to Seaborn's default
sns.set()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2672 entries, 0 to 2671
# Data columns (total 35 columns):
# player             2672 non-null object
# href               2672 non-null object
# height             2672 non-null float64
# age                2672 non-null int64
# tm                 2672 non-null object
# lg                 2672 non-null object
# pos                2672 non-null object
# g                  2672 non-null float64
# gs                 2672 non-null float64
# mp                 2672 non-null float64
# fg                 2672 non-null float64
# fga                2672 non-null float64
# fgp                2672 non-null float64
# threep             2672 non-null float64
# threepa            2672 non-null float64
# threepp            2672 non-null float64
# twop               2672 non-null float64
# twopa              2672 non-null float64
# twopp              2672 non-null float64
# efgp               2672 non-null float64
# ft                 2672 non-null float64
# fta                2672 non-null float64
# ftp                2672 non-null float64
# orb                2672 non-null float64
# drb                2672 non-null float64
# trb                2672 non-null float64
# ast                2672 non-null float64
# stl                2672 non-null float64
# blk                2672 non-null float64
# tov                2672 non-null float64
# pf                 2672 non-null float64
# pts                2672 non-null float64
# allstar            2672 non-null int64
# years_in_league    2672 non-null int64
# allstar_next       2672 non-null float64
# dtypes: float64(27), int64(3), object(5)
# memory usage: 730.7+ KB

# %% [markdown]
# I want to see if there are big differences between all star seasons and non-all star seasons.
#
# - The null hypothesis is that there is no significant difference between the mean values for all star seasons and non all star seasons.
# - The alternate hypothesis is that there is a significant difference between the means of both.
#
# The $\alpha$ value is 0.05.

# %%
eda_df = df.drop(['player', 'href', 'tm', 'lg', 'pos'], axis=1)
allstar = eda_df[eda_df.allstar_next == 1]
nostar = eda_df[eda_df.allstar_next == 0]

# %%
h_o = zip(allstar.columns, scipy.stats.ttest_ind(nostar, allstar, equal_var=False)[1])

print('Column: p-value')
for i in list(h_o):
    print(i[0], ':', i[1])
# Out:
# Column: p-value
# height : 2.3363110826575177e-10
# age : 1.3530571403409782e-19
# g : 1.0319206334295213e-26
# gs : 2.203272023732277e-138
# mp : 8.615339015552376e-225
# fg : 9.512420261702498e-222
# fga : 1.2499628976937351e-192
# fgp : 9.175188567875425e-33
# threep : 0.23643994830006035
# threepa : 0.20917961139783658
# threepp : 0.8289719961711538
# twop : 1.7671744451799767e-192
# twopa : 1.8161279633650965e-185
# twopp : 1.8939646515608085e-25
# efgp : 2.886798541888699e-14
# ft : 3.884657343199595e-169
# fta : 7.417377371668365e-168
# ftp : 1.2485380259006423e-05
# orb : 2.847104877545597e-34
# drb : 8.995896496407117e-69
# trb : 1.958597537763928e-63
# ast : 2.608890432839314e-37
# stl : 9.85044493351019e-56
# blk : 8.388546982037631e-31
# tov : 7.115370646081689e-153
# pf : 1.1759535941303408e-40
# pts : 2.4117069549436994e-225
# allstar : 4.3192007759160036e-153
# years_in_league : 1.5137778964694908e-15
# allstar_next : 0.0

# %% [markdown]
# In nearly every single category, there is a significant difference between allstars and non allstars. The only one's that are not significantly different are `threep`, `threepa`, and `threepp`. These significant differences make me believe that there is a way to predict whether a player will be an allstar the following year or not.
#
# I want to see the correlations between different values and the `allstar_next` column. I sorted it so I could see which columns are most highly correlated.

# %%
df.corr()['allstar_next'].sort_values(ascending=False)
# Out:
# allstar_next       1.000000
# pts                0.573396
# fg                 0.564337
# fta                0.552855
# ft                 0.551512
# twop               0.550808
# allstar            0.546563
# twopa              0.534989
# fga                0.525304
# tov                0.478085
# mp                 0.464114
# gs                 0.382436
# drb                0.352474
# trb                0.333242
# stl                0.319647
# ast                0.264651
# blk                0.258993
# pf                 0.248791
# orb                0.242183
# fgp                0.208432
# twopp              0.181338
# g                  0.181158
# efgp               0.131923
# height             0.122583
# ftp                0.078448
# threepa            0.025300
# threep             0.024124
# threepp            0.004057
# years_in_league   -0.137572
# age               -0.155200
# Name: allstar_next, dtype: float64

# %% [markdown]
# There are strong correlations for a variety of different categories and `allstar_next`. `pts`, `fg`, `fta`, `ft`, `twop`, `allstar`, `twopa`, and `fga` all have correlations above 0.5. The only two categories to have a negative correlation are `years_in_league` and `age` which both follow the same incremental increases but start at different points.
#
# After performing the same correlation tests on the rest of the columns, I came up with the following takeaways about the data:
#
# - `height` is positively correlated with stats typically associated with frontcourt players and negatively correlated with statistics typical of guards.
# - `age` is negatively associated with nearly every statistic.
# - `g` is not nearly as strongly correlated with other statistics as `gs` is.
# - `mp` is highly correlated with nearly every statistic outside of percentages
# - All the scoring statistics are correlated with each other (`pts`, `fga`, `fg`, `twopa`, `twop`, `ft`, `fta`)
# - `threepp` and `ftp` are positively correlated with each other while `threepp` is negatively correlated with both `twopp` and `fgp`
# - `ast` has strong positive correlation with both `tov` and `stl` which are both categories that ballhandlers would accumulate stats in.
# - `blk` has a strong positive correlation with `pf` which indicates that players that block shots also tend to foul more.
# - After scoring stats, the next most correlated category with whether a player was an allstar the following year is whether they were an allstar the year before and their turnovers.
#
#
#
# Next I want to create a scatter matrix of the columns that were highly correlated with `allstar_next` to see how related they are to each other. I am going to ignore `allstar` since it is a binary classifier.

# %%
high_cor = df.loc[:, ['pts', 'fg', 'fta', 'ft', 'twop', 'twopa', 'fga']]

_ = pd.plotting.scatter_matrix(high_cor)

# %% [markdown]
# There is a lot of multicolinearity occuring in this dataset. This makes sense considering most of these statistics measure scoring. Perhaps I should drop out every classifier directly related to scoring except `pts`.

# %%
pct = df.loc[:, ['fgp', 'twopp', 'threepp', 'ftp', 'efgp']]
print(pct.corr())
_ = pd.plotting.scatter_matrix(pct)
# Out:
#               fgp     twopp   threepp       ftp      efgp
# fgp      1.000000  0.913138 -0.379430 -0.261700  0.802337
# twopp    0.913138  1.000000 -0.254245 -0.189595  0.858702
# threepp -0.379430 -0.254245  1.000000  0.407187 -0.011449
# ftp     -0.261700 -0.189595  0.407187  1.000000 -0.031129
# efgp     0.802337  0.858702 -0.011449 -0.031129  1.000000

# %% [markdown]
# These relationships make sense logically. Three point shots are more difficult shots, so their relationship with overall field goal percentage would naturally be negative. Additionally, free throw percentage and three point percentage are correlated positively. This checks out as well since most three point shooters are also excellent foul shooters. Scouts will often reference college player's free throw percentage when predicting their potential to become a three point threat in the future.
#
# I want to take a look at each column's most correlated values.

# %%
for col in df.corr():
    vals = df.corr()[col].sort_values(ascending=False)
    print(vals)
    #print(vals[((vals < 1) & (vals > 0.5)) | (vals < 0.0)], '\n')
# Out:
# height             1.000000
# trb                0.666562
# blk                0.654793
# drb                0.632823
# orb                0.627873
# fgp                0.454391
# pf                 0.390094
# twopp              0.344068
# twop               0.250487
# efgp               0.223405
# twopa              0.190445
# fta                0.188012
# allstar            0.135164
# allstar_next       0.122583
# fg                 0.122319
# gs                 0.111749
# ft                 0.105159
# years_in_league    0.098522
# pts                0.071674
# age                0.069388
# mp                 0.041465
# g                  0.011374
# fga                0.005937
# tov               -0.094959
# stl               -0.329376
# ftp               -0.340469
# threep            -0.390775
# threepa           -0.410967
# threepp           -0.457938
# ast               -0.549347
# Name: height, dtype: float64
# age                1.000000
# years_in_league    0.955623
# ftp                0.077004
# height             0.069388
# efgp              -0.002756
# threep            -0.005908
# threepa           -0.015227
# threepp           -0.015914
# allstar           -0.030180
# twopp             -0.038896
# drb               -0.045488
# fgp               -0.052091
# blk               -0.063698
# trb               -0.079251
# ast               -0.097478
# gs                -0.132519
# orb               -0.134113
# allstar_next      -0.155200
# ft                -0.170668
# twop              -0.177126
# fg                -0.180685
# fga               -0.181171
# twopa             -0.181534
# pts               -0.181870
# g                 -0.184926
# pf                -0.191580
# fta               -0.194257
# mp                -0.195946
# tov               -0.212917
# stl               -0.214546
# Name: age, dtype: float64
# g                  1.000000
# gs                 0.582704
# mp                 0.402333
# fg                 0.319450
# pts                0.311555
# twop               0.286088
# fga                0.284280
# efgp               0.261970
# twopa              0.260433
# stl                0.256002
# allstar            0.249737
# pf                 0.246904
# twopp              0.234458
# ft                 0.231641
# fgp                0.223819
# fta                0.222885
# tov                0.220197
# trb                0.194160
# drb                0.190119
# allstar_next       0.181158
# orb                0.172258
# ast                0.162382
# blk                0.107628
# ftp                0.093639
# threep             0.091894
# threepp            0.087673
# threepa            0.078447
# height             0.011374
# age               -0.184926
# years_in_league   -0.205624
# Name: g, dtype: float64
# gs                 1.000000
# mp                 0.793752
# fg                 0.647104
# pts                0.633024
# fga                0.617231
# twop               0.599148
# twopa              0.586174
# g                  0.582704
# tov                0.548954
# fta                0.506322
# ft                 0.502958
# drb                0.461874
# allstar            0.459632
# stl                0.452559
# trb                0.442034
# pf                 0.426168
# allstar_next       0.382436
# ast                0.370849
# orb                0.332715
# fgp                0.278412
# twopp              0.261584
# blk                0.261441
# efgp               0.233110
# threep             0.125918
# threepa            0.124577
# height             0.111749
# ftp                0.065959
# threepp            0.028293
# years_in_league   -0.125100
# age               -0.132519
# Name: gs, dtype: float64
# mp                 1.000000
# fga                0.820861
# pts                0.817805
# fg                 0.813639
# gs                 0.793752
# twopa              0.744283
# twop               0.730389
# tov                0.722361
# ft                 0.679823
# fta                0.679034
# stl                0.570963
# drb                0.517848
# allstar            0.503170
# ast                0.490461
# trb                0.484159
# pf                 0.480097
# allstar_next       0.464114
# g                  0.402333
# orb                0.340749
# blk                0.247056
# threepa            0.244143
# threep             0.226629
# fgp                0.185964
# twopp              0.183963
# efgp               0.153453
# ftp                0.138793
# threepp            0.104735
# height             0.041465
# years_in_league   -0.186941
# age               -0.195946
# Name: mp, dtype: float64
# fg                 1.000000
# pts                0.978994
# fga                0.967532
# twop               0.944709
# twopa              0.939347
# mp                 0.813639
# ft                 0.804637
# fta                0.800274
# tov                0.727776
# gs                 0.647104
# allstar            0.633393
# allstar_next       0.564337
# drb                0.463294
# stl                0.456068
# trb                0.439576
# pf                 0.424208
# ast                0.360877
# orb                0.323396
# g                  0.319450
# fgp                0.294540
# blk                0.283636
# twopp              0.267765
# efgp               0.196258
# ftp                0.174373
# threepa            0.149831
# threep             0.136027
# height             0.122319
# threepp            0.061620
# years_in_league   -0.150870
# age               -0.180685
# Name: fg, dtype: float64
# fga                1.000000
# pts                0.967781
# fg                 0.967532
# twopa              0.904034
# twop               0.866696
# mp                 0.820861
# ft                 0.788380
# fta                0.761309
# tov                0.737220
# gs                 0.617231
# allstar            0.591425
# allstar_next       0.525304
# stl                0.500200
# ast                0.428012
# drb                0.370303
# pf                 0.350545
# trb                0.329304
# threepa            0.303717
# g                  0.284280
# threep             0.275240
# ftp                0.249503
# orb                0.196087
# blk                0.163599
# threepp            0.160386
# fgp                0.075618
# twopp              0.070549
# efgp               0.027022
# height             0.005937
# years_in_league   -0.145703
# age               -0.181171
# Name: fga, dtype: float64
# fgp                1.000000
# twopp              0.913138
# efgp               0.802337
# orb                0.538893
# trb                0.501472
# blk                0.474546
# height             0.454391
# drb                0.442732
# twop               0.431416
# pf                 0.390596
# fg                 0.294540
# fta                0.291109
# twopa              0.290007
# gs                 0.278412
# allstar            0.227114
# pts                0.223872
# g                  0.223819
# ft                 0.210843
# allstar_next       0.208432
# mp                 0.185964
# tov                0.127660
# fga                0.075618
# stl               -0.040080
# age               -0.052091
# years_in_league   -0.054148
# ast               -0.151511
# ftp               -0.261700
# threepp           -0.379430
# threep            -0.423622
# threepa           -0.471034
# Name: fgp, dtype: float64
# threep             1.000000
# threepa            0.987074
# threepp            0.595842
# ftp                0.426156
# ast                0.300289
# fga                0.275240
# pts                0.247026
# mp                 0.226629
# stl                0.218319
# fg                 0.136027
# gs                 0.125918
# tov                0.104427
# efgp               0.102583
# g                  0.091894
# ft                 0.085940
# allstar            0.074173
# allstar_next       0.024124
# years_in_league    0.021666
# age               -0.005908
# fta               -0.008686
# twopa             -0.156481
# twop              -0.195876
# twopp             -0.213276
# drb               -0.215042
# pf                -0.246478
# trb               -0.320940
# blk               -0.371932
# height            -0.390775
# fgp               -0.423622
# orb               -0.481040
# Name: threep, dtype: float64
# threepa            1.000000
# threep             0.987074
# threepp            0.581237
# ftp                0.412259
# ast                0.334750
# fga                0.303717
# pts                0.261791
# stl                0.256699
# mp                 0.244143
# fg                 0.149831
# tov                0.142029
# gs                 0.124577
# ft                 0.107431
# g                  0.078447
# allstar            0.077167
# efgp               0.033345
# allstar_next       0.025300
# years_in_league    0.019099
# fta                0.014902
# age               -0.015227
# twopa             -0.132586
# twop              -0.178175
# drb               -0.212706
# twopp             -0.236134
# pf                -0.243697
# trb               -0.320405
# blk               -0.381710
# height            -0.410967
# fgp               -0.471034
# orb               -0.484056
# Name: threepa, dtype: float64
# threepp            1.000000
# threep             0.595842
# threepa            0.581237
# ftp                0.407187
# ast                0.306469
# stl                0.207439
# fga                0.160386
# pts                0.120206
# mp                 0.104735
# g                  0.087673
# fg                 0.061620
# tov                0.043322
# allstar            0.031046
# gs                 0.028293
# ft                 0.005972
# allstar_next       0.004057
# efgp              -0.011449
# age               -0.015914
# years_in_league   -0.018087
# fta               -0.085578
# twopa             -0.094153
# twop              -0.136625
# twopp             -0.254245
# drb               -0.294019
# pf                -0.297288
# fgp               -0.379430
# trb               -0.382712
# blk               -0.414219
# height            -0.457938
# orb               -0.499248
# Name: threepp, dtype: float64
# twop               1.000000
# twopa              0.981597
# fg                 0.944709
# pts                0.887386
# fga                0.866696
# fta                0.795228
# ft                 0.768319
# mp                 0.730389
# tov                0.685640
# allstar            0.602304
# gs                 0.599148
# allstar_next       0.550808
# trb                0.541269
# drb                0.529842
# pf                 0.501193
# orb                0.478986
# fgp                0.431416
# blk                0.403768
# stl                0.378701
# twopp              0.335365
# g                  0.286088
# ast                0.257822
# height             0.250487
# efgp               0.159892
# ftp                0.032012
# threepp           -0.136625
# years_in_league   -0.156664
# age               -0.177126
# threepa           -0.178175
# threep            -0.195876
# Name: twop, dtype: float64
# twopa              1.000000
# twop               0.981597
# fg                 0.939347
# fga                0.904034
# pts                0.889377
# fta                0.785290
# ft                 0.771980
# mp                 0.744283
# tov                0.703158
# gs                 0.586174
# allstar            0.580486
# allstar_next       0.534989
# trb                0.486125
# drb                0.480533
# pf                 0.473860
# orb                0.420843
# stl                0.405161
# blk                0.341471
# ast                0.295003
# fgp                0.290007
# g                  0.260433
# height             0.190445
# twopp              0.179465
# ftp                0.074942
# efgp               0.013211
# threepp           -0.094153
# threepa           -0.132586
# threep            -0.156481
# years_in_league   -0.160008
# age               -0.181534
# Name: twopa, dtype: float64
# twopp              1.000000
# fgp                0.913138
# efgp               0.858702
# trb                0.406039
# orb                0.399996
# drb                0.376988
# blk                0.371426
# height             0.344068
# twop               0.335365
# pf                 0.295113
# fg                 0.267765
# gs                 0.261584
# fta                0.243618
# g                  0.234458
# pts                0.221731
# allstar            0.213019
# mp                 0.183963
# ft                 0.181428
# allstar_next       0.181338
# twopa              0.179465
# tov                0.118514
# fga                0.070549
# stl                0.020067
# years_in_league   -0.032864
# age               -0.038896
# ast               -0.079860
# ftp               -0.189595
# threep            -0.213276
# threepa           -0.236134
# threepp           -0.254245
# Name: twopp, dtype: float64
# efgp               1.000000
# twopp              0.858702
# fgp                0.802337
# g                  0.261970
# trb                0.254831
# drb                0.251515
# blk                0.248132
# gs                 0.233110
# height             0.223405
# orb                0.220612
# fg                 0.196258
# pts                0.183682
# pf                 0.169778
# allstar            0.166665
# twop               0.159892
# mp                 0.153453
# allstar_next       0.131923
# fta                0.130747
# threep             0.102583
# ft                 0.095278
# threepa            0.033345
# fga                0.027022
# tov                0.017369
# twopa              0.013211
# age               -0.002756
# years_in_league   -0.004476
# threepp           -0.011449
# stl               -0.023639
# ftp               -0.031129
# ast               -0.086077
# Name: efgp, dtype: float64
# ft                 1.000000
# fta                0.972055
# pts                0.884706
# fg                 0.804637
# fga                0.788380
# twopa              0.771980
# twop               0.768319
# tov                0.730188
# mp                 0.679823
# allstar            0.603762
# allstar_next       0.551512
# gs                 0.502958
# drb                0.422366
# trb                0.397800
# pf                 0.386891
# stl                0.374299
# ast                0.335627
# orb                0.286513
# blk                0.244024
# ftp                0.241017
# g                  0.231641
# fgp                0.210843
# twopp              0.181428
# threepa            0.107431
# height             0.105159
# efgp               0.095278
# threep             0.085940
# threepp            0.005972
# years_in_league   -0.137998
# age               -0.170668
# Name: ft, dtype: float64
# fta                1.000000
# ft                 0.972055
# pts                0.862084
# fg                 0.800274
# twop               0.795228
# twopa              0.785290
# fga                0.761309
# tov                0.735377
# mp                 0.679034
# allstar            0.598641
# allstar_next       0.552855
# drb                0.510602
# gs                 0.506322
# trb                0.502265
# pf                 0.464123
# orb                0.406738
# stl                0.354392
# blk                0.354265
# fgp                0.291109
# ast                0.278813
# twopp              0.243618
# g                  0.222885
# height             0.188012
# efgp               0.130747
# ftp                0.053598
# threepa            0.014902
# threep            -0.008686
# threepp           -0.085578
# years_in_league   -0.156669
# age               -0.194257
# Name: fta, dtype: float64
# ftp                1.000000
# threep             0.426156
# threepa            0.412259
# threepp            0.407187
# ast                0.275532
# fga                0.249503
# pts                0.248822
# ft                 0.241017
# fg                 0.174373
# mp                 0.138793
# allstar            0.107273
# stl                0.106643
# tov                0.094514
# g                  0.093639
# allstar_next       0.078448
# age                0.077004
# twopa              0.074942
# gs                 0.065959
# years_in_league    0.056282
# fta                0.053598
# twop               0.032012
# efgp              -0.031129
# twopp             -0.189595
# pf                -0.231118
# fgp               -0.261700
# drb               -0.271380
# height            -0.340469
# trb               -0.349946
# blk               -0.368155
# orb               -0.450225
# Name: ftp, dtype: float64
# orb                1.000000
# trb                0.892896
# drb                0.768246
# blk                0.666495
# height             0.627873
# pf                 0.591318
# fgp                0.538893
# twop               0.478986
# twopa              0.420843
# fta                0.406738
# twopp              0.399996
# mp                 0.340749
# gs                 0.332715
# fg                 0.323396
# ft                 0.286513
# pts                0.259383
# allstar_next       0.242183
# allstar            0.238320
# efgp               0.220612
# tov                0.212053
# fga                0.196087
# g                  0.172258
# stl               -0.003462
# age               -0.134113
# years_in_league   -0.135145
# ast               -0.277036
# ftp               -0.450225
# threep            -0.481040
# threepa           -0.484056
# threepp           -0.499248
# Name: orb, dtype: float64
# drb                1.000000
# trb                0.974025
# orb                0.768246
# blk                0.674966
# height             0.632823
# pf                 0.566656
# twop               0.529842
# mp                 0.517848
# fta                0.510602
# twopa              0.480533
# fg                 0.463294
# gs                 0.461874
# fgp                0.442732
# pts                0.433412
# ft                 0.422366
# allstar            0.393759
# twopp              0.376988
# fga                0.370303
# tov                0.359178
# allstar_next       0.352474
# efgp               0.251515
# g                  0.190119
# stl                0.096228
# years_in_league   -0.019244
# age               -0.045488
# ast               -0.091514
# threepa           -0.212706
# threep            -0.215042
# ftp               -0.271380
# threepp           -0.294019
# Name: drb, dtype: float64
# trb                1.000000
# drb                0.974025
# orb                0.892896
# blk                0.709769
# height             0.666562
# pf                 0.607106
# twop               0.541269
# fta                0.502265
# fgp                0.501472
# twopa              0.486125
# mp                 0.484159
# gs                 0.442034
# fg                 0.439576
# twopp              0.406039
# ft                 0.397800
# pts                0.395978
# allstar            0.360800
# allstar_next       0.333242
# fga                0.329304
# tov                0.327354
# efgp               0.254831
# g                  0.194160
# stl                0.066590
# years_in_league   -0.061263
# age               -0.079251
# ast               -0.162003
# threepa           -0.320405
# threep            -0.320940
# ftp               -0.349946
# threepp           -0.382712
# Name: trb, dtype: float64
# ast                1.000000
# tov                0.659762
# stl                0.637977
# mp                 0.490461
# fga                0.428012
# pts                0.396747
# gs                 0.370849
# fg                 0.360877
# ft                 0.335627
# threepa            0.334750
# threepp            0.306469
# allstar            0.303723
# threep             0.300289
# twopa              0.295003
# fta                0.278813
# ftp                0.275532
# allstar_next       0.264651
# twop               0.257822
# g                  0.162382
# pf                 0.011200
# twopp             -0.079860
# efgp              -0.086077
# drb               -0.091514
# years_in_league   -0.093978
# age               -0.097478
# fgp               -0.151511
# trb               -0.162003
# orb               -0.277036
# blk               -0.281079
# height            -0.549347
# Name: ast, dtype: float64
# stl                1.000000
# ast                0.637977
# mp                 0.570963
# tov                0.569887
# fga                0.500200
# pts                0.467454
# fg                 0.456068
# gs                 0.452559
# twopa              0.405161
# twop               0.378701
# ft                 0.374299
# fta                0.354392
# allstar            0.323111
# allstar_next       0.319647
# threepa            0.256699
# g                  0.256002
# pf                 0.251718
# threep             0.218319
# threepp            0.207439
# ftp                0.106643
# drb                0.096228
# trb                0.066590
# twopp              0.020067
# orb               -0.003462
# efgp              -0.023639
# fgp               -0.040080
# blk               -0.052277
# age               -0.214546
# years_in_league   -0.224833
# height            -0.329376
# Name: stl, dtype: float64
# blk                1.000000
# trb                0.709769
# drb                0.674966
# orb                0.666495
# height             0.654793
# pf                 0.500796
# fgp                0.474546
# twop               0.403768
# twopp              0.371426
# fta                0.354265
# twopa              0.341471
# fg                 0.283636
# allstar            0.268545
# gs                 0.261441
# allstar_next       0.258993
# efgp               0.248132
# mp                 0.247056
# ft                 0.244024
# pts                0.231750
# fga                0.163599
# tov                0.162774
# g                  0.107628
# stl               -0.052277
# age               -0.063698
# years_in_league   -0.070230
# ast               -0.281079
# ftp               -0.368155
# threep            -0.371932
# threepa           -0.381710
# threepp           -0.414219
# Name: blk, dtype: float64
# tov                1.000000
# pts                0.754152
# fga                0.737220
# fta                0.735377
# ft                 0.730188
# fg                 0.727776
# mp                 0.722361
# twopa              0.703158
# twop               0.685640
# ast                0.659762
# stl                0.569887
# gs                 0.548954
# allstar            0.517290
# allstar_next       0.478085
# pf                 0.454648
# drb                0.359178
# trb                0.327354
# g                  0.220197
# orb                0.212053
# blk                0.162774
# threepa            0.142029
# fgp                0.127660
# twopp              0.118514
# threep             0.104427
# ftp                0.094514
# threepp            0.043322
# efgp               0.017369
# height            -0.094959
# years_in_league   -0.192800
# age               -0.212917
# Name: tov, dtype: float64
# pf                 1.000000
# trb                0.607106
# orb                0.591318
# drb                0.566656
# twop               0.501193
# blk                0.500796
# mp                 0.480097
# twopa              0.473860
# fta                0.464123
# tov                0.454648
# gs                 0.426168
# fg                 0.424208
# pts                0.390830
# fgp                0.390596
# height             0.390094
# ft                 0.386891
# fga                0.350545
# twopp              0.295113
# stl                0.251718
# allstar_next       0.248791
# g                  0.246904
# allstar            0.228130
# efgp               0.169778
# ast                0.011200
# age               -0.191580
# years_in_league   -0.215444
# ftp               -0.231118
# threepa           -0.243697
# threep            -0.246478
# threepp           -0.297288
# Name: pf, dtype: float64
# pts                1.000000
# fg                 0.978994
# fga                0.967781
# twopa              0.889377
# twop               0.887386
# ft                 0.884706
# fta                0.862084
# mp                 0.817805
# tov                0.754152
# allstar            0.645178
# gs                 0.633024
# allstar_next       0.573396
# stl                0.467454
# drb                0.433412
# ast                0.396747
# trb                0.395978
# pf                 0.390830
# g                  0.311555
# threepa            0.261791
# orb                0.259383
# ftp                0.248822
# threep             0.247026
# blk                0.231750
# fgp                0.223872
# twopp              0.221731
# efgp               0.183682
# threepp            0.120206
# height             0.071674
# years_in_league   -0.147301
# age               -0.181870
# Name: pts, dtype: float64
# allstar            1.000000
# pts                0.645178
# fg                 0.633393
# ft                 0.603762
# twop               0.602304
# fta                0.598641
# fga                0.591425
# twopa              0.580486
# allstar_next       0.546563
# tov                0.517290
# mp                 0.503170
# gs                 0.459632
# drb                0.393759
# trb                0.360800
# stl                0.323111
# ast                0.303723
# blk                0.268545
# g                  0.249737
# orb                0.238320
# pf                 0.228130
# fgp                0.227114
# twopp              0.213019
# efgp               0.166665
# height             0.135164
# ftp                0.107273
# threepa            0.077167
# threep             0.074173
# threepp            0.031046
# years_in_league   -0.009148
# age               -0.030180
# Name: allstar, dtype: float64
# years_in_league    1.000000
# age                0.955623
# height             0.098522
# ftp                0.056282
# threep             0.021666
# threepa            0.019099
# efgp              -0.004476
# allstar           -0.009148
# threepp           -0.018087
# drb               -0.019244
# twopp             -0.032864
# fgp               -0.054148
# trb               -0.061263
# blk               -0.070230
# ast               -0.093978
# gs                -0.125100
# orb               -0.135145
# allstar_next      -0.137572
# ft                -0.137998
# fga               -0.145703
# pts               -0.147301
# fg                -0.150870
# twop              -0.156664
# fta               -0.156669
# twopa             -0.160008
# mp                -0.186941
# tov               -0.192800
# g                 -0.205624
# pf                -0.215444
# stl               -0.224833
# Name: years_in_league, dtype: float64
# allstar_next       1.000000
# pts                0.573396
# fg                 0.564337
# fta                0.552855
# ft                 0.551512
# twop               0.550808
# allstar            0.546563
# twopa              0.534989
# fga                0.525304
# tov                0.478085
# mp                 0.464114
# gs                 0.382436
# drb                0.352474
# trb                0.333242
# stl                0.319647
# ast                0.264651
# blk                0.258993
# pf                 0.248791
# orb                0.242183
# fgp                0.208432
# twopp              0.181338
# g                  0.181158
# efgp               0.131923
# height             0.122583
# ftp                0.078448
# threepa            0.025300
# threep             0.024124
# threepp            0.004057
# years_in_league   -0.137572
# age               -0.155200
# Name: allstar_next, dtype: float64

# %% [markdown]
# After exploring my data, I have put together these takeaways to think about when designing my model:
#
# 1) **The data is unbalanced.** There are over twice as many samples that were not allstars the following year as there were allstars. In order to deal with this, I will have to structure my test data appropriately. My initial thought is to take a subsample of both categories that is the size of the minority group (`allstar_next == 1`).
#
# 2) **The differences between `allstar_next` == 1 and `allstar_next` == 0 are significant.** There is a definite difference in nearly every category, so I feel confident I can produce a model capable of categorizing test data.
#
# 3) **There are instances of multicolinearity.** In order to ensure my model does not overfit, I may need to reduce the categories I use. However, since the purpose of this model is to classify players, the underlying coefficients do not matter as much, so I could proceed without worry. Being cognizant of potential multicolinearity can help me if the model produces results that are nonsensical or illogical.
