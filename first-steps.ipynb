# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a641fa32c83e> in <module>()
#       3 import pandas as pd
#       4 import seaborn as sns
# ----> 5 from cleaning.py import df
#
# ModuleNotFoundError: No module named 'cleaning.py'; 'cleaning' is not a package

# %%
# I am using min-max feature scaling normalization because
# I want to compare player's stats relative to their apex.
def normalize(ls):
    '''Performs min-max feature scaling normalization on a sequence'''
    return [(num - min(ls))/(max(ls)-min(ls)) for num in ls]

df = pd.read_csv('all-stats-clean.csv', header=0, index_col=0)

# %%
# There are many instances of players who took seasons off due to injury/
# health concerns, military service, or to play elsewhere. These instances 
# screwed up the data scraping process so they require additional cleaning.
# This is done by systematically going through and checking Basketball
# Reference and adjusting their stats accordingly by hand. I wanted to do it
# programmatically, but the juice wasn't worth the squeeze.

df = df.replace('None', np.nan)
df.columns = df.columns.str.lower()

# %%
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='ignore')

# Add All Star category
allstar= {'allstar':[]}
for i, row in df.iterrows():
    try:
        len(row['season'])
        allstar['allstar'].append(0)
    except:
        allstar['allstar'].append(1)
df['allstar'] = allstar['allstar']


# I will also need to deal with players who were traded mid season. I am going
# to solely look at their totals over the course of the entire season
df = df.loc[df.age.shift(1) != df.age]
df = df.reset_index(drop=True)

# %%
df.describe()
# Out:
#                age            g           gs           mp           fg  \
# count  3956.000000  3867.000000  2678.000000  3818.000000  3834.000000
# mean     27.928969    68.590897    53.157954    31.195364     5.916745
# std       4.542510    16.673757    29.175766     7.883603     2.539932
# min      18.000000     1.000000     0.000000     1.800000     0.000000
# 25%      24.000000    64.000000    27.000000    26.900000     4.000000
# 50%      28.000000    75.000000    66.000000    33.300000     5.900000
# 75%      31.000000    80.000000    78.000000    36.875000     7.700000
# max      43.000000    88.000000    82.000000    48.500000    20.000000
#
#                fga          fg%           3p          3pa          3p%  \
# count  3834.000000  3834.000000  2793.000000  2811.000000  2625.000000
# mean     12.715962     1.232978     0.733906     2.450729     0.279507
# std       5.198693    18.004452     0.812113     5.455761     0.147848
# min       0.400000     0.000000     0.000000     0.000000     0.000000
# 25%       8.800000     0.427000     0.000000     0.100000     0.213000
# 50%      12.800000     0.460000     0.400000     1.400000     0.324000
# 75%      16.400000     0.498000     1.300000     3.600000     0.372000
# max      39.500000   448.000000     5.100000    79.000000     1.000000
#
#           ...               orb          drb          trb          ast  \
# count     ...       3087.000000  3071.000000  3823.000000  3852.000000
# mean      ...          1.562520     4.137126     6.229741     3.590421
# std       ...          1.175941     2.337452     3.863537     2.333859
# min       ...          0.000000     0.000000     0.000000     0.000000
# 25%       ...          0.600000     2.300000     3.300000     1.900000
# 50%       ...          1.200000     3.500000     5.200000     3.000000
# 75%       ...          2.300000     5.600000     8.500000     4.800000
# max       ...          7.200000    13.700000    27.200000    14.500000
#
#                stl          blk          tov           pf          pts  \
# count  3099.000000  3100.000000  2936.000000  3876.000000  3878.000000
# mean      1.108772     0.784032     2.141519     2.519221    15.674523
# std       0.568381     1.309786     0.968293     0.748000     6.753456
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.700000     0.200000     1.400000     2.000000    10.600000
# 50%       1.000000     0.400000     2.100000     2.500000    15.600000
# 75%       1.400000     1.000000     2.800000     3.000000    20.300000
# max       4.200000    26.400000    18.200000     4.600000    50.400000
#
#            allstar
# count  3956.000000
# mean      0.368807
# std       0.482542
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['player', 'href', 'height', 'season', 'age', 'tm', 'lg', 'pos', 'g',
#        'gs', 'mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', '2p', '2pa', '2p%',
#        'efg%', 'ft', 'fta', 'ft%', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk',
#        'tov', 'pf', 'pts', 'allstar'],
#       dtype='object')

# %%
df.rename(columns={'fg%':'fgp','3p':'threep', '3pa':'threepa',
                  '3p%':'threepp', '2p':'twop', '2pa':'twopa',
                  '2p%':'twopp', 'efg%':'efgp', 'ft%':'ftp'}, inplace=True)

# %%
df.head()
# Out:
#                 player                       href height season  age   tm  \
# 0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86    NaN   22  MIL
# 1  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86    NaN   23  MIL
# 2  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86    NaN   24  MIL
# 3  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86    NaN   25  MIL
# 4  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86    NaN   26  MIL
#
#     lg pos     g  gs   ...     orb   drb   trb  ast  stl  blk  tov   pf   pts  \
# 0  NBA   C  82.0 NaN   ...     NaN   NaN  14.5  4.1  NaN  NaN  NaN  3.5  28.8
# 1  NBA   C  82.0 NaN   ...     NaN   NaN  16.0  3.3  NaN  NaN  NaN  3.2  31.7
# 2  NBA   C  81.0 NaN   ...     NaN   NaN  16.6  4.6  NaN  NaN  NaN  2.9  34.8
# 3  NBA   C  76.0 NaN   ...     NaN   NaN  16.1  5.0  NaN  NaN  NaN  2.7  30.2
# 4  NBA   C  81.0 NaN   ...     3.5  11.0  14.5  4.8  1.4  3.5  NaN  2.9  27.0
#
#    allstar
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#
# [5 rows x 34 columns]

# %%
df.head()
# Out:
#    Unnamed: 0               Player                       href Height Season  \
# 0         0.0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86   None
# 1         1.0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86   None
# 2         2.0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86   None
# 3         3.0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86   None
# 4         4.0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86   None
#
#    Age   Tm   Lg Pos     G  ...    FT%   ORB   DRB   TRB  AST   STL   BLK  \
# 0   22  MIL  NBA   C  82.0  ...   .653  None  None  14.5  4.1  None  None
# 1   23  MIL  NBA   C  82.0  ...   .690  None  None  16.0  3.3  None  None
# 2   24  MIL  NBA   C  81.0  ...   .689  None  None  16.6  4.6  None  None
# 3   25  MIL  NBA   C  76.0  ...   .713  None  None  16.1  5.0  None  None
# 4   26  MIL  NBA   C  81.0  ...   .702   3.5  11.0  14.5  4.8   1.4   3.5
#
#     TOV   PF   PTS
# 0  None  3.5  28.8
# 1  None  3.2  31.7
# 2  None  2.9  34.8
# 3  None  2.7  30.2
# 4  None  2.9  27.0
#
# [5 rows x 34 columns]

# %%
# create new dataframe with each players data normalized
# against every season in their career
unique = df['player'].unique()
all_norm_df = pd.DataFrame()
for player in unique:
    pnormdf = pd.DataFrame()
    playerdf = df[df['player'] == player]
    years_in_league = np.array(range(1, len(playerdf)+1))
    for col in playerdf:    
        if playerdf[col].dtypes == np.float64:
            statdf = playerdf[col]
            try:
                normdf = pd.DataFrame({col:normalize(statdf)})
                pnormdf = pd.concat([pnormdf, normdf], axis=1)
            except:
                pass
    pnormdf['allstar'] = playerdf['allstar']
    pnormdf['player'] = player
    pnormdf['years_in_league'] = years_in_league
    all_norm_df = pd.concat([all_norm_df, pnormdf])
all_norm_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Drew\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'player'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-176c181c6061> in <module>()
#       1 # create new dataframe with each players data normalized
#       2 # against every season in their career
# ----> 3 unique = df['player'].unique()
#       4 all_norm_df = pd.DataFrame()
#       5 for player in unique:
#
# C:\Users\Drew\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\Users\Drew\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Drew\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# C:\Users\Drew\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\Users\Drew\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'player'

# %%
#rearrange order of dataframe so name and years_in_league are first columns
columns = list(all_norm_df.columns)
columns = ['player', 'years_in_league'] + columns
columns.pop(24)
columns.pop()
all_norm_df = all_norm_df[columns]
all_norm_df = all_norm_df.reset_index(drop=True)
all_norm_df.head()
# Out:
#                 player  years_in_league               player  years_in_league  \
# 0  Kareem Abdul-Jabbar                1  Kareem Abdul-Jabbar                1
# 1  Kareem Abdul-Jabbar                2  Kareem Abdul-Jabbar                2
# 2  Kareem Abdul-Jabbar                3  Kareem Abdul-Jabbar                3
# 3  Kareem Abdul-Jabbar                4  Kareem Abdul-Jabbar                4
# 4  Kareem Abdul-Jabbar                5  Kareem Abdul-Jabbar                5
#
#          2p       2p%    2pa  3p  3p%  3pa ...         ft       ft%       fta  \
# 0  0.712871  0.322835  0.825 NaN  NaN  NaN ...   0.934783  0.000000  1.000000
# 1  0.871287  0.787402  0.850 NaN  NaN  NaN ...   0.891304  0.284615  0.884058
# 2  1.000000  0.763780  1.000 NaN  NaN  NaN ...   1.000000  0.276923  0.985507
# 3  0.861386  0.606299  0.900 NaN  NaN  NaN ...   0.586957  0.461538  0.565217
# 4  0.742574  0.488189  0.800 NaN  NaN  NaN ...   0.434783  0.376923  0.434783
#
#       g  gs        mp   pf       pts  stl  tov
# 0  1.00 NaN  0.948357  0.9  0.757085  NaN  NaN
# 1  1.00 NaN  0.807512  0.6  0.874494  NaN  NaN
# 2  0.95 NaN  1.000000  0.3  1.000000  NaN  NaN
# 3  0.70 NaN  0.934272  0.1  0.813765  NaN  NaN
# 4  0.95 NaN  0.981221  0.3  0.684211  NaN  NaN
#
# [5 rows x 28 columns]

# %%
# Some stats are not positive indicators such as turnovers
# so I want used the inverse of their values from the overall values
all_norm_df.tov = 1-all_norm_df.tov

# %%
# create individual normalized season sum column
s = [row[2:].sum() for i, row in all_norm_df.iterrows()]
season_sum = pd.DataFrame({'season_sum':s})

# %%
# create individual normalized season average column
# the average performance in each statistic
m = [row[2:].mean() for i, row in all_norm_df.iterrows()]
season_mean = pd.DataFrame({'season_mean':m})

# %%
statistic_df = pd.concat([all_norm_df[['player', 'years_in_league']],
                          season_sum, season_mean], axis=1)

# %%
statistic_df.head(10)
# Out:
#                 player  years_in_league  season_sum  season_mean
# 0  Kareem Abdul-Jabbar                1   12.116465     0.712733
# 1  Kareem Abdul-Jabbar                2   13.603501     0.800206
# 2  Kareem Abdul-Jabbar                3   14.605082     0.859122
# 3  Kareem Abdul-Jabbar                4   12.360202     0.727071
# 4  Kareem Abdul-Jabbar                5   11.397593     0.670447
# 5  Kareem Abdul-Jabbar                6   11.613782     0.683164
# 6  Kareem Abdul-Jabbar                7   12.662827     0.744872
# 7  Kareem Abdul-Jabbar                8   11.865249     0.697956
# 8  Kareem Abdul-Jabbar                9    9.440216     0.555307
# 9  Kareem Abdul-Jabbar               10   11.432148     0.672479

# %%
statistic_df.describe()
# Out:
#        years_in_league   season_sum  season_mean
# count      3956.000000  3956.000000  3885.000000
# mean          7.324065    11.292040     0.552580
# std           4.371802     5.307444     0.203683
# min           1.000000     0.000000     0.000000
# 25%           4.000000     7.339929     0.421777
# 50%           7.000000    11.599877     0.588492
# 75%          10.000000    15.777758     0.711796
# max          21.000000    22.690476     0.974768

# %%
# Show seasons in a player's career where they performed in top 75% 
# for all categories
print(len(statistic_df[statistic_df['season_mean'] > 0.75]))
statistic_df[statistic_df['season_mean'] > 0.75].head(20)
# Out:
# 641
#                   player  years_in_league  season_sum  season_mean
# 1    Kareem Abdul-Jabbar                2   13.603501     0.800206
# 2    Kareem Abdul-Jabbar                3   14.605082     0.859122
# 42          Bill Russell                4    9.065811     0.755484
# 44          Bill Russell                6   10.405016     0.867085
# 58           Kobe Bryant                7   20.443757     0.817750
# 61           Kobe Bryant               10   20.822053     0.832882
# 62           Kobe Bryant               11   20.064829     0.802593
# 63           Kobe Bryant               12   19.502857     0.780114
# 74      Wilt Chamberlain                3    9.048562     0.754047
# 107           Tim Duncan                6   19.905438     0.796218
# 147        John Havlicek                8    9.075513     0.756293
# 148        John Havlicek                9   10.702509     0.891876
# 149        John Havlicek               10    9.730791     0.810899
# 157      Oscar Robertson                2    9.682308     0.806859
# 158      Oscar Robertson                3    9.055317     0.754610
# 159      Oscar Robertson                4   10.424902     0.868742
# 160      Oscar Robertson                5    9.257137     0.771428
# 161      Oscar Robertson                6    9.581156     0.798430
# 162      Oscar Robertson                7    9.565102     0.797092
# 171            Bob Cousy                2    8.923906     0.811264

# %% [markdown]
# This process shows a bias towards older players as well as players who were less consistent through their careers. For instance, this line of thinking has led to results that ignore Michael Jordan and say Wilt Chamberlain had a single peak year. Perhaps by adding a measurement of a player's individual season against the entire sample, I can identify above average players from a historical sample and then identify how those seasons fit into their individual career narrative.

# %%
# Create

# %%
hist_norm_df = pd.DataFrame()
for col in df:    
    if df[col].dtypes == np.float64:
        statdf = df[col]
        try:
            normdf = pd.DataFrame({col:normalize(statdf)})
        except:
            pass
    hist_norm_df = pd.concat([hist_norm_df, normdf], axis=1)

# %%
hist_norm_df = hist_norm_df.iloc[:, 7:-2]
hist_norm_df.head(20)
# Out:
#          pts         g  gs        mp     fg       fga    fg%  3p  3pa  3p%  \
# 0   0.000000  0.931034 NaN  0.884368  0.570  0.554987  0.518 NaN  NaN  NaN
# 1   0.496732  0.931034 NaN  0.820128  0.650  0.565217  0.577 NaN  NaN  NaN
# 2   0.568627  0.919540 NaN  0.907923  0.715  0.626598  0.574 NaN  NaN  NaN
# 3   0.901961  0.862069 NaN  0.877944  0.645  0.585678  0.554 NaN  NaN  NaN
# 4   0.830065  0.919540 NaN  0.899358  0.585  0.544757  0.539 NaN  NaN  NaN
# 5   0.594771  0.735632 NaN  0.867238  0.625  0.613811  0.513 NaN  NaN  NaN
# 6   0.718954  0.931034 NaN  0.843683  0.555  0.529412  0.529 NaN  NaN  NaN
# 7   1.000000  0.931034 NaN  0.749465  0.540  0.468031  0.579 NaN  NaN  NaN
# 8        NaN  0.701149 NaN  0.743041  0.535  0.485934  0.550 NaN  NaN  NaN
# 9        NaN  0.908046 NaN  0.807281  0.485  0.419437  0.577 NaN  NaN  NaN
# 10       NaN  0.931034 NaN  0.781585  0.510  0.421995  0.604 NaN  NaN  NaN
# 11       NaN  0.908046 NaN  0.758030  0.525  0.455243  0.574 NaN  NaN  NaN
# 12       NaN  0.862069 NaN  0.715203  0.495  0.427110  0.579 NaN  NaN  NaN
# 13       NaN  0.896552 NaN  0.653105  0.455  0.386189  0.588 NaN  NaN  NaN
# 14       NaN  0.908046 NaN  0.663812  0.450  0.386189  0.578 NaN  NaN  NaN
# 15       NaN  0.896552 NaN  0.674518  0.460  0.381074  0.599 NaN  NaN  NaN
# 16       NaN  0.896552 NaN  0.674518  0.480  0.421995  0.564 NaN  NaN  NaN
# 17       NaN  0.885057 NaN  0.631692  0.360  0.314578  0.564 NaN  NaN  NaN
# 18       NaN  0.908046 NaN  0.580300  0.300  0.278772  0.532 NaN  NaN  NaN
# 19       NaN  0.839080 NaN  0.451820  0.210  0.217391  0.475 NaN  NaN  NaN
#
#       ...          fta       ft%  orb  drb       trb       ast  stl  blk  tov  \
# 0     ...     0.535294  0.116607  NaN  NaN  0.533088  0.282759  NaN  NaN  NaN
# 1     ...     0.488235  0.123214  NaN  NaN  0.588235  0.227586  NaN  NaN  NaN
# 2     ...     0.529412  0.123036  NaN  NaN  0.610294  0.317241  NaN  NaN  NaN
# 3     ...     0.358824  0.127321  NaN  NaN  0.591912  0.344828  NaN  NaN  NaN
# 4     ...     0.305882  0.125357  NaN  NaN  0.533088  0.331034  NaN  NaN  NaN
# 5     ...     0.388235  0.136250  NaN  NaN  0.514706  0.282759  NaN  NaN  NaN
# 6     ...     0.458824  0.125536  NaN  NaN  0.621324  0.344828  NaN  NaN  NaN
# 7     ...     0.382353  0.125179  NaN  NaN  0.488971  0.268966  NaN  NaN  NaN
# 8     ...     0.329412  0.139821  NaN  NaN  0.474265  0.296552  NaN  NaN  NaN
# 9     ...     0.347059  0.131429  NaN  NaN  0.470588  0.372414  NaN  NaN  NaN
# 10    ...     0.341176  0.136607  NaN  NaN  0.397059  0.310345  NaN  NaN  NaN
# 11    ...     0.405882  0.136786  NaN  NaN  0.378676  0.234483  NaN  NaN  NaN
# 12    ...     0.341176  0.126071  NaN  NaN  0.319853  0.206897  NaN  NaN  NaN
# 13    ...     0.276471  0.133750  NaN  NaN  0.275735  0.172414  NaN  NaN  NaN
# 14    ...     0.288235  0.129107  NaN  NaN  0.268382  0.179310  NaN  NaN  NaN
# 15    ...     0.294118  0.130714  NaN  NaN  0.290441  0.220690  NaN  NaN  NaN
# 16    ...     0.329412  0.136607  NaN  NaN  0.224265  0.241379  NaN  NaN  NaN
# 17    ...     0.258824  0.127500  NaN  NaN  0.246324  0.179310  NaN  NaN  NaN
# 18    ...     0.200000  0.136071  NaN  NaN  0.220588  0.117241  NaN  NaN  NaN
# 19    ...     0.129412  0.131964  NaN  NaN  0.165441  0.068966  NaN  NaN  NaN
#
#           pf
# 0   0.760870
# 1   0.695652
# 2   0.630435
# 3   0.586957
# 4   0.630435
# 5   0.695652
# 6   0.782609
# 7   0.695652
# 8   0.630435
# 9   0.630435
# 10  0.565217
# 11  0.673913
# 12  0.630435
# 13  0.608696
# 14  0.565217
# 15  0.652174
# 16  0.673913
# 17  0.673913
# 18  0.586957
# 19  0.565217
#
# [20 rows x 25 columns]

# %%
hist_norm_df['player'] = df.loc[:, 'player']
hist_norm_df['years_in_league'] = all_norm_df.loc[:, 'years_in_league']
hist_norm_df['allstar'] = all_norm_df.loc[:, 'allstar']

# %%
# There is some issue with the drb column which needs investigation
columns.remove('drb')
hist_norm_df = hist_norm_df[columns]

# %%
hist_norm_df.describe()
# Out:
#        years_in_league           2p          2p%          2pa   3p  3p%  3pa  \
# count      3956.000000  3121.000000  3128.000000  3128.000000  0.0  0.0  0.0
# mean          7.324065     0.131996     0.040258     0.364614  NaN  NaN  NaN
# std           4.371802     0.084975     0.067686     0.179920  NaN  NaN  NaN
# min           1.000000     0.000000     0.000000     0.000000  NaN  NaN  NaN
# 25%           4.000000     0.075610     0.031586     0.219512  NaN  NaN  NaN
# 50%           7.000000     0.124390     0.033793     0.351916  NaN  NaN  NaN
# 75%          10.000000     0.175610     0.035931     0.494774  NaN  NaN  NaN
# max          21.000000     1.000000     1.000000     1.000000  NaN  NaN  NaN
#
#          allstar          ast  blk     ...               fta            g  \
# count  20.000000  3852.000000  0.0     ...       3826.000000  3859.000000
# mean    0.950000     0.248503  NaN     ...          0.259260     0.776808
# std     0.223607     0.161677  NaN     ...          0.144887     0.191830
# min     0.000000     0.000000  NaN     ...          0.000000     0.000000
# 25%     1.000000     0.131034  NaN     ...          0.147059     0.724138
# 50%     1.000000     0.206897  NaN     ...          0.241176     0.850575
# 75%     1.000000     0.331034  NaN     ...          0.347059     0.908046
# max     1.000000     1.000000  NaN     ...          1.000000     1.000000
#
#         gs           mp  orb           pf       pts  stl  tov          trb
# count  0.0  3810.000000  0.0  3882.000000  8.000000  0.0  0.0  3823.000000
# mean   NaN     0.629156  NaN     0.548098  0.638889  NaN  NaN     0.228937
# std    NaN     0.168857  NaN     0.162880  0.311182  NaN  NaN     0.142010
# min    NaN     0.000000  NaN     0.000000  0.000000  NaN  NaN     0.000000
# 25%    NaN     0.537473  NaN     0.434783  0.550654  NaN  NaN     0.121324
# 50%    NaN     0.674518  NaN     0.543478  0.656863  NaN  NaN     0.191176
# 75%    NaN     0.749465  NaN     0.673913  0.848039  NaN  NaN     0.308824
# max    NaN     1.000000  NaN     1.000000  1.000000  NaN  NaN     1.000000
#
# [8 rows x 26 columns]

# %%
all_norm_df.describe()
# Out:
#        years_in_league           2p          2p%          2pa           3p  \
# count      3956.000000  3095.000000  3095.000000  3095.000000  2223.000000
# mean          7.324065     0.560029     0.529906     0.556614     0.416117
# std           4.371802     0.309553     0.299503     0.310799     0.346681
# min           1.000000     0.000000     0.000000     0.000000     0.000000
# 25%           4.000000     0.322005     0.302023     0.306624     0.070197
# 50%           7.000000     0.605634     0.550000     0.602484     0.391304
# 75%          10.000000     0.816870     0.765862     0.811823     0.705882
# max          21.000000     1.000000     1.000000     1.000000     1.000000
#
#                3p%          3pa    allstar          ast          blk  \
# count  2262.000000  2440.000000  20.000000  3850.000000  2762.000000
# mean      0.533973     0.429453   0.950000     0.527239     0.484870
# std       0.330134     0.345306   0.223607     0.308864     0.322675
# min       0.000000     0.000000   0.000000     0.000000     0.000000
# 25%       0.272898     0.090404   1.000000     0.285714     0.250000
# 50%       0.589417     0.397674   1.000000     0.548387     0.500000
# 75%       0.804575     0.717531   1.000000     0.775510     0.714286
# max       1.000000     1.000000   1.000000     1.000000     1.000000
#
#           ...               fta            g           gs           mp  \
# count     ...       3823.000000  3859.000000  2424.000000  3672.000000
# mean      ...          0.526151     0.725836     0.620714     0.643166
# std       ...          0.313162     0.318430     0.373111     0.313725
# min       ...          0.000000     0.000000     0.000000     0.000000
# 25%       ...          0.268336     0.586984     0.248904     0.440311
# 50%       ...          0.555556     0.863636     0.774421     0.742331
# 75%       ...          0.781250     0.971429     0.961538     0.899273
# max       ...          1.000000     1.000000     1.000000     1.000000
#
#                orb           pf          pts          stl          tov  \
# count  2807.000000  3882.000000  3884.000000  2745.000000  2665.000000
# mean      0.509640     0.561930     0.573992     0.522915     0.470232
# std       0.314124     0.306047     0.311983     0.306359     0.308837
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.250000     0.333333     0.340426     0.285714     0.217391
# 50%       0.500000     0.600000     0.622510     0.533333     0.437500
# 75%       0.750000     0.812500     0.831528     0.750000     0.714286
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                trb
# count  3705.000000
# mean      0.546120
# std       0.310339
# min       0.000000
# 25%       0.305556
# 50%       0.583333
# 75%       0.800000
# max       1.000000
#
# [8 rows x 27 columns]

# %%
df
# Out:
#                    player                       href height   season  age  \
# 0     Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   22
# 1     Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   23
# 2     Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   24
# 3     Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   25
# 4     Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   26
# 5     Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   27
# 6     Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   28
# 7     Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   29
# 8     Kareem Abdul-Jabbar  /players/a/abdulka01.html     86  1977-78   30
# 9     Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   31
# 10    Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   32
# 11    Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   33
# 12    Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   34
# 13    Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   35
# 14    Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   36
# 15    Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   37
# 16    Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   38
# 17    Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   39
# 18    Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   40
# 19    Kareem Abdul-Jabbar  /players/a/abdulka01.html     86      NaN   41
# 20         Michael Jordan  /players/j/jordami01.html    6-6      NaN   21
# 21         Michael Jordan  /players/j/jordami01.html    6-6      NaN   22
# 22         Michael Jordan  /players/j/jordami01.html    6-6      NaN   23
# 23         Michael Jordan  /players/j/jordami01.html    6-6      NaN   24
# 24         Michael Jordan  /players/j/jordami01.html    6-6      NaN   25
# 25         Michael Jordan  /players/j/jordami01.html    6-6      NaN   26
# 26         Michael Jordan  /players/j/jordami01.html    6-6      NaN   27
# 27         Michael Jordan  /players/j/jordami01.html    6-6      NaN   28
# 28         Michael Jordan  /players/j/jordami01.html    6-6      NaN   29
# 29         Michael Jordan  /players/j/jordami01.html    6-6  1993-94   30
# ...                   ...                        ...    ...      ...  ...
# 3926         Jrue Holiday  /players/h/holidjr01.html     76  2011-12   21
# 3927         Jrue Holiday  /players/h/holidjr01.html     76      NaN   22
# 3928         Jrue Holiday  /players/h/holidjr01.html     76  2013-14   23
# 3929         Jrue Holiday  /players/h/holidjr01.html     76  2014-15   24
# 3930         Jrue Holiday  /players/h/holidjr01.html     76  2015-16   25
# 3931         Jrue Holiday  /players/h/holidjr01.html     76  2016-17   26
# 3932         Jrue Holiday  /players/h/holidjr01.html     76  2017-18   27
# 3933         Jrue Holiday  /players/h/holidjr01.html     76  2018-19   28
# 3934       Raymond Felton  /players/f/feltora01.html     73  2005-06   21
# 3935       Raymond Felton  /players/f/feltora01.html     73  2006-07   22
# 3936       Raymond Felton  /players/f/feltora01.html     73  2007-08   23
# 3937       Raymond Felton  /players/f/feltora01.html     73  2008-09   24
# 3938       Raymond Felton  /players/f/feltora01.html     73  2009-10   25
# 3939       Raymond Felton  /players/f/feltora01.html     73  2010-11   26
# 3940       Raymond Felton  /players/f/feltora01.html     73  2011-12   27
# 3941       Raymond Felton  /players/f/feltora01.html     73  2012-13   28
# 3942       Raymond Felton  /players/f/feltora01.html     73  2013-14   29
# 3943       Raymond Felton  /players/f/feltora01.html     73  2014-15   30
# 3944       Raymond Felton  /players/f/feltora01.html     73  2015-16   31
# 3945       Raymond Felton  /players/f/feltora01.html     73  2016-17   32
# 3946       Raymond Felton  /players/f/feltora01.html     73  2017-18   33
# 3947       Raymond Felton  /players/f/feltora01.html     73  2018-19   34
# 3948       Nikola Vucevic  /players/v/vucevni01.html     84  2011-12   21
# 3949       Nikola Vucevic  /players/v/vucevni01.html     84  2012-13   22
# 3950       Nikola Vucevic  /players/v/vucevni01.html     84  2013-14   23
# 3951       Nikola Vucevic  /players/v/vucevni01.html     84  2014-15   24
# 3952       Nikola Vucevic  /players/v/vucevni01.html     84  2015-16   25
# 3953       Nikola Vucevic  /players/v/vucevni01.html     84  2016-17   26
# 3954       Nikola Vucevic  /players/v/vucevni01.html     84  2017-18   27
# 3955       Nikola Vucevic  /players/v/vucevni01.html     84      NaN   28
#
#        tm   lg   pos     g    gs   ...     orb   drb   trb  ast  stl  blk  \
# 0     MIL  NBA     C  82.0   NaN   ...     NaN   NaN  14.5  4.1  NaN  NaN
# 1     MIL  NBA     C  82.0   NaN   ...     NaN   NaN  16.0  3.3  NaN  NaN
# 2     MIL  NBA     C  81.0   NaN   ...     NaN   NaN  16.6  4.6  NaN  NaN
# 3     MIL  NBA     C  76.0   NaN   ...     NaN   NaN  16.1  5.0  NaN  NaN
# 4     MIL  NBA     C  81.0   NaN   ...     3.5  11.0  14.5  4.8  1.4  3.5
# 5     MIL  NBA     C  65.0   NaN   ...     3.0  11.0  14.0  4.1  1.0  3.3
# 6     LAL  NBA     C  82.0   NaN   ...     3.3  13.5  16.9  5.0  1.5  4.1
# 7     LAL  NBA     C  82.0   NaN   ...     3.2  10.0  13.3  3.9  1.2  3.2
# 8     LAL  NBA     C  62.0   NaN   ...     3.0   9.9  12.9  4.3  1.7  3.0
# 9     LAL  NBA     C  80.0   NaN   ...     2.6  10.2  12.8  5.4  1.0  4.0
# 10    LAL  NBA     C  82.0   NaN   ...     2.3   8.5  10.8  4.5  1.0  3.4
# 11    LAL  NBA     C  80.0   NaN   ...     2.5   7.8  10.3  3.4  0.7  2.9
# 12    LAL  NBA     C  76.0  76.0   ...     2.3   6.4   8.7  3.0  0.8  2.7
# 13    LAL  NBA     C  79.0  79.0   ...     2.1   5.4   7.5  2.5  0.8  2.2
# 14    LAL  NBA     C  80.0  80.0   ...     2.1   5.2   7.3  2.6  0.7  1.8
# 15    LAL  NBA     C  79.0  79.0   ...     2.1   5.8   7.9  3.2  0.8  2.1
# 16    LAL  NBA     C  79.0  79.0   ...     1.7   4.4   6.1  3.5  0.8  1.6
# 17    LAL  NBA     C  78.0  78.0   ...     1.9   4.8   6.7  2.6  0.6  1.2
# 18    LAL  NBA     C  80.0  80.0   ...     1.5   4.5   6.0  1.7  0.6  1.2
# 19    LAL  NBA     C  74.0  74.0   ...     1.4   3.1   4.5  1.0  0.5  1.1
# 20    CHI  NBA    SG  82.0  82.0   ...     2.0   4.5   6.5  5.9  2.4  0.8
# 21    CHI  NBA    SG  18.0   7.0   ...     1.3   2.3   3.6  2.9  2.1  1.2
# 22    CHI  NBA    SG  82.0  82.0   ...     2.0   3.2   5.2  4.6  2.9  1.5
# 23    CHI  NBA    SG  82.0  82.0   ...     1.7   3.8   5.5  5.9  3.2  1.6
# 24    CHI  NBA    SG  81.0  81.0   ...     1.8   6.2   8.0  8.0  2.9  0.8
# 25    CHI  NBA    SG  82.0  82.0   ...     1.7   5.1   6.9  6.3  2.8  0.7
# 26    CHI  NBA    SG  82.0  82.0   ...     1.4   4.6   6.0  5.5  2.7  1.0
# 27    CHI  NBA    SG  80.0  80.0   ...     1.1   5.3   6.4  6.1  2.3  0.9
# 28    CHI  NBA    SG  78.0  78.0   ...     1.7   5.0   6.7  5.5  2.8  0.8
# 29    NaN  NaN  None   NaN   NaN   ...     NaN   NaN   NaN  NaN  NaN  NaN
# ...   ...  ...   ...   ...   ...   ...     ...   ...   ...  ...  ...  ...
# 3926  PHI  NBA    PG  65.0  65.0   ...     0.9   2.4   3.3  4.5  1.6  0.3
# 3927  PHI  NBA    PG  78.0  78.0   ...     1.1   3.1   4.2  8.0  1.6  0.4
# 3928  NOP  NBA    PG  34.0  34.0   ...     0.8   3.4   4.2  7.9  1.6  0.4
# 3929  NOP  NBA    PG  40.0  37.0   ...     0.8   2.6   3.4  6.9  1.6  0.6
# 3930  NOP  NBA    PG  65.0  23.0   ...     0.4   2.6   3.0  6.0  1.4  0.3
# 3931  NOP  NBA    PG  67.0  61.0   ...     0.7   3.3   3.9  7.3  1.5  0.7
# 3932  NOP  NBA    SG  81.0  81.0   ...     0.8   3.7   4.5  6.0  1.5  0.8
# 3933  NOP  NBA    SG  67.0  67.0   ...     1.1   3.9   5.0  7.7  1.6  0.8
# 3934  CHA  NBA    PG  80.0  54.0   ...     1.0   2.4   3.3  5.6  1.3  0.1
# 3935  CHA  NBA    PG  78.0  75.0   ...     0.7   2.8   3.4  7.0  1.5  0.1
# 3936  CHA  NBA    PG  79.0  79.0   ...     0.5   2.5   3.0  7.4  1.2  0.2
# 3937  CHA  NBA    PG  82.0  81.0   ...     0.7   3.1   3.8  6.7  1.5  0.4
# 3938  CHA  NBA    PG  80.0  80.0   ...     0.7   2.9   3.6  5.6  1.5  0.3
# 3939  TOT  NBA    PG  75.0  54.0   ...     0.6   2.9   3.6  8.3  1.7  0.1
# 3940  POR  NBA    PG  60.0  56.0   ...     0.5   2.0   2.5  6.5  1.3  0.2
# 3941  NYK  NBA    PG  68.0  68.0   ...     0.8   2.1   2.9  5.5  1.4  0.2
# 3942  NYK  NBA    PG  65.0  65.0   ...     0.8   2.2   3.0  5.6  1.2  0.4
# 3943  DAL  NBA    PG  29.0   3.0   ...     0.1   0.8   0.9  1.4  0.4  0.1
# 3944  DAL  NBA    PG  80.0  31.0   ...     0.5   2.8   3.2  3.6  0.9  0.2
# 3945  LAC  NBA    PG  80.0  11.0   ...     0.4   2.3   2.7  2.4  0.8  0.3
# 3946  OKC  NBA    PG  82.0   2.0   ...     0.3   1.6   1.9  2.5  0.6  0.2
# 3947  OKC  NBA    PG  33.0   0.0   ...     0.1   0.9   1.0  1.6  0.3  0.2
# 3948  PHI  NBA     C  51.0  15.0   ...     1.7   3.1   4.8  0.6  0.4  0.7
# 3949  ORL  NBA     C  77.0  77.0   ...     3.5   8.4  11.9  1.9  0.8  1.0
# 3950  ORL  NBA     C  57.0  57.0   ...     3.2   7.7  11.0  1.8  1.1  0.8
# 3951  ORL  NBA     C  74.0  74.0   ...     3.2   7.7  10.9  2.0  0.7  0.7
# 3952  ORL  NBA     C  65.0  60.0   ...     2.7   6.2   8.9  2.8  0.8  1.1
# 3953  ORL  NBA     C  75.0  55.0   ...     2.3   8.0  10.4  2.8  1.0  1.0
# 3954  ORL  NBA     C  57.0  57.0   ...     1.8   7.4   9.2  3.4  1.0  1.1
# 3955  ORL  NBA     C  80.0  80.0   ...     2.8   9.2  12.0  3.8  1.0  1.1
#
#       tov   pf   pts  allstar
# 0     NaN  3.5  28.8        1
# 1     NaN  3.2  31.7        1
# 2     NaN  2.9  34.8        1
# 3     NaN  2.7  30.2        1
# 4     NaN  2.9  27.0        1
# 5     NaN  3.2  30.0        1
# 6     NaN  3.6  27.7        1
# 7     NaN  3.2  26.2        1
# 8     3.4  2.9  25.8        0
# 9     3.5  2.9  23.8        1
# 10    3.6  2.6  24.8        1
# 11    3.1  3.1  26.2        1
# 12    3.0  2.9  23.9        1
# 13    2.5  2.8  21.8        1
# 14    2.8  2.6  21.5        1
# 15    2.5  3.0  22.0        1
# 16    2.6  3.1  23.4        1
# 17    2.4  3.1  17.5        1
# 18    2.0  2.7  14.6        1
# 19    1.3  2.6  10.1        1
# 20    3.5  3.5  28.2        1
# 21    2.5  2.6  22.7        1
# 22    3.3  2.9  37.1        1
# 23    3.1  3.3  35.0        1
# 24    3.6  3.0  32.5        1
# 25    3.0  2.9  33.6        1
# 26    2.5  2.8  31.5        1
# 27    2.5  2.5  30.1        1
# 28    2.7  2.4  32.6        1
# 29    NaN  NaN   NaN        0
# ...   ...  ...   ...      ...
# 3926  2.1  2.1  13.5        0
# 3927  3.7  2.2  17.7        1
# 3928  3.1  2.7  14.3        0
# 3929  2.3  2.8  14.8        0
# 3930  2.6  2.3  16.8        0
# 3931  2.9  2.0  15.4        0
# 3932  2.6  2.5  19.0        0
# 3933  3.1  2.2  21.2        0
# 3934  2.3  2.3  11.9        0
# 3935  2.9  2.3  14.0        0
# 3936  2.7  2.3  14.4        0
# 3937  2.8  2.3  14.2        0
# 3938  2.1  2.2  12.1        0
# 3939  2.9  2.0  15.5        0
# 3940  2.8  2.0  11.4        0
# 3941  2.3  1.9  13.9        0
# 3942  2.0  2.4   9.7        0
# 3943  0.6  0.6   3.7        0
# 3944  1.5  1.8   9.5        0
# 3945  1.0  1.6   6.7        0
# 3946  0.9  1.1   6.9        0
# 3947  0.4  0.9   4.3        0
# 3948  0.6  2.2   5.5        0
# 3949  1.8  2.8  13.1        0
# 3950  2.0  3.0  14.2        0
# 3951  2.0  3.0  19.3        0
# 3952  1.9  2.7  18.2        0
# 3953  1.6  2.4  14.6        0
# 3954  1.9  2.5  16.5        0
# 3955  2.0  2.0  20.8        1
#
# [3956 rows x 34 columns]

# %%
df.head()
# Out:
#    Unnamed: 0               Player                       href Height Season  \
# 0         0.0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86   None
# 1         1.0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86   None
# 2         2.0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86   None
# 3         3.0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86   None
# 4         4.0  Kareem Abdul-Jabbar  /players/a/abdulka01.html     86   None
#
#    Age   Tm   Lg Pos     G  ...    FT%   ORB   DRB   TRB  AST   STL   BLK  \
# 0   22  MIL  NBA   C  82.0  ...   .653  None  None  14.5  4.1  None  None
# 1   23  MIL  NBA   C  82.0  ...   .690  None  None  16.0  3.3  None  None
# 2   24  MIL  NBA   C  81.0  ...   .689  None  None  16.6  4.6  None  None
# 3   25  MIL  NBA   C  76.0  ...   .713  None  None  16.1  5.0  None  None
# 4   26  MIL  NBA   C  81.0  ...   .702   3.5  11.0  14.5  4.8   1.4   3.5
#
#     TOV   PF   PTS
# 0  None  3.5  28.8
# 1  None  3.2  31.7
# 2  None  2.9  34.8
# 3  None  2.7  30.2
# 4  None  2.9  27.0
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['Player', 'href', 'Height', 'Season', 'Age', 'Tm', 'Lg', 'Pos', 'G',
#        'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%',
#        'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS'],
#       dtype='object')
